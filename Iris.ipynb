# %%
import numpy as np
import pandas as pd

# %%
#data=pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f',])

# %%
#data = {'Gander':[1,2,3],'age':[21,32,40],'group':[3,4,5]}

# %%
#d=pd.DataFrame(data,columns=['Gander','age','group'])

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.cov()
# Out:
#                         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1887.500000      25.782886     -7.492282      67.667785
# SepalLengthCm    25.782886       0.685694     -0.039268       1.273682
# SepalWidthCm     -7.492282      -0.039268      0.188004      -0.321713
# PetalLengthCm    67.667785       1.273682     -0.321713       3.113179
# PetalWidthCm     29.832215       0.516904     -0.117981       1.296387
#
#                PetalWidthCm
# Id                29.832215
# SepalLengthCm      0.516904
# SepalWidthCm      -0.117981
# PetalLengthCm      1.296387
# PetalWidthCm       0.582414

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
#df[loan_data_set].unique()

# %%
#f.values

# %%
df.sort_values(by=['SepalLengthCm', 'SepalWidthCm'],ascending=[True,True])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 42    43            4.4           3.2            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# 3      4            4.6           3.1            1.5           0.2
# 47    48            4.6           3.2            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 22    23            4.6           3.6            1.0           0.2
# 2      3            4.7           3.2            1.3           0.2
# 29    30            4.7           3.2            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 45    46            4.8           3.0            1.4           0.3
# ...

# %%
df['SepalLengthCm'].sum()
# Out:
# 876.5

# %%
df[0:4]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df.loc[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df.loc[0:3,['SepalWidthCm','PetalLengthCm']]
# Out:
#    SepalWidthCm  PetalLengthCm
# 0           3.5            1.4
# 1           3.0            1.4
# 2           3.2            1.3
# 3           3.1            1.5

# %%
df.iloc[0:2]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df.iloc[0:2] #using range,first 2 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df.iloc[0:2,2:4]
# Out:
#    SepalWidthCm  PetalLengthCm
# 0           3.5            1.4
# 1           3.0            1.4

# %%
df.iat[2,2]
# Out:
# 3.2

# %%
df.T
# Out:
#                        0            1            2            3    \
# Id                       1            2            3            4
# SepalLengthCm          5.1          4.9          4.7          4.6
# SepalWidthCm           3.5            3          3.2          3.1
# PetalLengthCm          1.4          1.4          1.3          1.5
# PetalWidthCm           0.2          0.2          0.2          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7    \
# Id                       5            6            7            8
# SepalLengthCm            5          5.4          4.6            5
# SepalWidthCm           3.6          3.9          3.4          3.4
# PetalLengthCm          1.4          1.7          1.4          1.5
# PetalWidthCm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
# ...

# %%
df[df['SepalLengthCm']>7.5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#             Species
# 105  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 122  Iris-virginica
# 131  Iris-virginica
# 135  Iris-virginica

# %%
df(df['SepalLengthCm'])isin([7.7],[7.9'])
# Out:
#   File "<ipython-input-69-e78aa6e2bf0b>", line 1
#     df(df['SepalLengthCm'])isin([7.7],[7.9'])
#                               ^
# SyntaxError: invalid syntax

# %%
df(df['SepalLengthCm']>7.5) & (df['SepalLengthCm']>3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-48f281ecb1de> in <module>
# ----> 1 df(df['SepalLengthCm']>7.5)&(df['SepalLengthCm']>3)
#
# TypeError: 'DataFrame' object is not callable

# %%
df.cov()
# Out:
#                         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1887.500000      25.782886     -7.492282      67.667785
# SepalLengthCm    25.782886       0.685694     -0.039268       1.273682
# SepalWidthCm     -7.492282      -0.039268      0.188004      -0.321713
# PetalLengthCm    67.667785       1.273682     -0.321713       3.113179
# PetalWidthCm     29.832215       0.516904     -0.117981       1.296387
#
#                PetalWidthCm
# Id                29.832215
# SepalLengthCm      0.516904
# SepalWidthCm      -0.117981
# PetalLengthCm      1.296387
# PetalWidthCm       0.582414

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000089CEAC8>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.cov()
# Out:
#                         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1887.500000      25.782886     -7.492282      67.667785
# SepalLengthCm    25.782886       0.685694     -0.039268       1.273682
# SepalWidthCm     -7.492282      -0.039268      0.188004      -0.321713
# PetalLengthCm    67.667785       1.273682     -0.321713       3.113179
# PetalWidthCm     29.832215       0.516904     -0.117981       1.296387
#
#                PetalWidthCm
# Id                29.832215
# SepalLengthCm      0.516904
# SepalWidthCm      -0.117981
# PetalLengthCm      1.296387
# PetalWidthCm       0.582414

# %%
df.boxplot()

# %% [markdown]
# # Merge /Join

# %%
data = {
         'emp_id': ['1', '2', '3', '4', '5'],
         'first_name': ['Jason', 'Andy', 'Allen', 'Alice', 'Amy'],
         'last_name': ['Larkin', 'Jacob', 'A', 'AA', 'Jackson']}
df_1 = pd.DataFrame(data, columns = ['emp_id', 'first_name', 'last_name'])
data = {
         'emp_id': ['4', '5', '6', '7'],
         'first_name': ['Brian', 'Shize', 'Kim', 'Jose'],
         'last_name': ['Alexander', 'Suma', 'Mike', 'G']}
df_2 = pd.DataFrame(data, columns = ['emp_id', 'first_name', 'last_name'])

# %%
df_1
# Out:
#   emp_id first_name last_name
# 0      1      Jason    Larkin
# 1      2       Andy     Jacob
# 2      3      Allen         A
# 3      4      Alice        AA
# 4      5        Amy   Jackson

# %%
df_2
# Out:
#   emp_id first_name  last_name
# 0      4      Brian  Alexander
# 1      5      Shize       Suma
# 2      6        Kim       Mike
# 3      7       Jose          G

# %%
# Usingconcat

df = pd.concat([df_1,df_2])
df
# Out:
#   emp_id first_name  last_name
# 0      1      Jason     Larkin
# 1      2       Andy      Jacob
# 2      3      Allen          A
# 3      4      Alice         AA
# 4      5        Amy    Jackson
# 0      4      Brian  Alexander
# 1      5      Shize       Suma
# 2      6        Kim       Mike
# 3      7       Jose          G

# %% [markdown]
# ## using append

# %%
df_1.append(df_2)
# Out:
#   emp_id first_name  last_name
# 0      1      Jason     Larkin
# 1      2       Andy      Jacob
# 2      3      Allen          A
# 3      4      Alice         AA
# 4      5        Amy    Jackson
# 0      4      Brian  Alexander
# 1      5      Shize       Suma
# 2      6        Kim       Mike
# 3      7       Jose          G

# %%
# Join the two dataframe along columns
pd.concat([df_1,df_2],axis=1)
# Out:
#   emp_id first_name last_name emp_id first_name  last_name
# 0      1      Jason    Larkin      4      Brian  Alexander
# 1      2       Andy     Jacob      5      Shize       Suma
# 2      3      Allen         A      6        Kim       Mike
# 3      4      Alice        AA      7       Jose          G
# 4      5        Amy   Jackson    NaN        NaN        NaN

# %%
# Marge two dataframes
# in this case only the emp_id's present in both table will be joined
pd.merge(df_1,df_2,on='emp_id')
# Out:
#   emp_id first_name_x last_name_x first_name_y last_name_y
# 0      4        Alice          AA        Brian   Alexander
# 1      5          Amy     Jackson        Shize        Suma

# %% [markdown]
# ## join

# %%
# 1 left join two dataframes

#left join

pd.merge(df_1,df_2, on ='emp_id',how='left')
# Out:
#   emp_id first_name_x last_name_x first_name_y last_name_y
# 0      1        Jason      Larkin          NaN         NaN
# 1      2         Andy       Jacob          NaN         NaN
# 2      3        Allen           A          NaN         NaN
# 3      4        Alice          AA        Brian   Alexander
# 4      5          Amy     Jackson        Shize        Suma
