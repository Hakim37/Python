# %%
for num1 in range(1,100):
    for i in range(2,num1):
        if num1%i == 0:
            j = num1/i
            print('not prime')
            break #to move to the next number,the # first fo 
        else :
            print(num1,'is aprime numberss
# Out:
# 3 is aprime number
# not prime
# 5 is aprime number
# 5 is aprime number
# 5 is aprime number
# not prime
# 7 is aprime number
# 7 is aprime number
# 7 is aprime number
# 7 is aprime number
# 7 is aprime number
# not prime
# 9 is aprime number
# not prime
# not prime
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# 11 is aprime number
# not prime
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# 13 is aprime number
# not prime
# 15 is aprime number
# not prime
# not prime
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# 17 is aprime number
# ...
